# %%
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime

# Display settings
pd.set_option("display.max_columns", None)

# File path (update if needed)
file_path = "Dataset\Healthcare Insurance Claims Management Dataset.xlsx"

# Load workbook
xls = pd.ExcelFile(file_path)

# Load all sheets into a dictionary
dfs = {sheet: pd.read_excel(file_path, sheet_name=sheet) for sheet in xls.sheet_names}

dfs.keys()
# Out:
# dict_keys(['Claims_Fact_raw', 'Provider_Master_raw', 'Member_Master_raw', 'Policy_Master_raw', 'Procedure_Master', 'Diagnosis_Master_ICD'])

# %%
for name, df in dfs.items():
    print(f"\n===== {name} =====")
    print("Rows:", len(df))
    print("Columns:", df.columns.tolist())
# Out:
# ===== Claims_Fact_raw =====
# Rows: 12000
# Columns: ['ClaimID', 'MemberID', 'PolicyID', 'ProviderID', 'ClaimType', 'ClaimSubmissionDate', 'AdmissionDate', 'DischargeDate', 'ClaimedAmount', 'ApprovedAmount', 'ICDCode(s)', 'ProcedureCode(s)', 'PreAuthNumber', 'PreAuthStatus', 'QueryRaiseDate', 'SettlementDate', 'TPANotes', 'Currency', 'NetworkStatus']
#
# ===== Provider_Master_raw =====
# Rows: 350
# Columns: ['ProviderID', 'ProviderName', 'Location', 'City', 'State', 'NetworkType', 'PackageRates']
#
# ===== Member_Master_raw =====
# Rows: 9000
# Columns: ['MemberID', 'AgeBand', 'Gender', 'City', 'State', 'PolicyID']
#
# ===== Policy_Master_raw =====
# Rows: 3000
# Columns: ['PolicyID', 'PolicyType', 'CoverageLimit', 'StartDate', 'EndDate', 'PremiumAmount']
#
# ===== Procedure_Master =====
# Rows: 120
# Columns: ['ProcedureCode', 'ProcedureCategory', 'StandardRate', 'LOSStandard']
#
# ===== Diagnosis_Master_ICD =====
# Rows: 60
# Columns: ['ICDCode', 'DiagnosisCategory', 'ValidProcedureCategories']

# %%
claims = dfs['Claims_Fact_raw']
providers = dfs['Provider_Master_raw']
members = dfs['Member_Master_raw']
policies = dfs['Policy_Master_raw']
procedures = dfs['Procedure_Master']
diagnosis = dfs['Diagnosis_Master_ICD']

# %%
audit_log = []

def log_issue(table, column, issue_type, rule, count, sample=None):
    audit_log.append({
        "table": table,
        "column": column,
        "issue_type": issue_type,
        "rule": rule,
        "rows_affected": count,
        "sample_values": sample
    })

# %%
# ----------------------------------------------
# 5. Primary Key Duplicate Checks
# ----------------------------------------------

# Claims_Fact: ClaimID
dups = claims[claims.duplicated(subset=['ClaimID'], keep=False)]
log_issue("Claims_Fact", "ClaimID", "Duplicate Key", "ClaimID must be unique", 
          len(dups), dups['ClaimID'].head().tolist())

# Provider
dups = providers[providers.duplicated(subset=['ProviderID'], keep=False)]
log_issue("Provider_Master", "ProviderID", "Duplicate Key", "ProviderID must be unique", 
          len(dups),dups['ProviderID'].head().tolist())

# Member
dups = members[members.duplicated(subset=['MemberID'], keep=False)]
log_issue("Member_Master", "MemberID", "Duplicate Key", "MemberID must be unique", 
          len(dups),dups['MemberID'].head().tolist())

# Policy
dups = policies[policies.duplicated(subset=['PolicyID'], keep=False)]
log_issue("Policy_Master", "PolicyID", "Duplicate Key", "PolicyID must be unique", 
          len(dups),dups['PolicyID'].head().tolist())

# %%
# ----------------------------------------------
# 6. Normalize Dates
# ----------------------------------------------
date_cols = [
    'ClaimSubmissionDate','AdmissionDate','DischargeDate','QueryRaiseDate','SettlementDate'
]

for col in date_cols:
    if col in claims.columns:
        claims[col] = pd.to_datetime(claims[col], errors='coerce')

# %% [markdown]
# # Date Logic Audit

# %%
invalid_stay = claims[claims['DischargeDate'] < claims['AdmissionDate']]
log_issue("Claims_Fact", "DischargeDate", "Invalid Date Order",
          "DischargeDate < AdmissionDate", len(invalid_stay),
          invalid_stay[['ClaimID','AdmissionDate','DischargeDate']].head().to_dict())

# %%
invalid_cycle = claims[claims['SettlementDate'] < claims['ClaimSubmissionDate']]
log_issue("Claims_Fact", "SettlementDate", "Invalid Date Order",
          "SettlementDate < ClaimSubmissionDate", len(invalid_cycle),invalid_cycle[['ClaimID','SettlementDate','ClaimSubmissionDate']].head().to_dict())

# %%
missing_discharge = claims[claims['DischargeDate'].isna()]
log_issue("Claims_Fact", "DischargeDate", "Missing", "DischargeDate is NULL",
          len(missing_discharge),missing_discharge['ClaimID'].head().to_dict())

missing_settlement = claims[claims['SettlementDate'].isna()]
log_issue("Claims_Fact", "SettlementDate", "Missing", "SettlementDate is NULL",
          len(missing_settlement),missing_settlement['ClaimID'].head().to_dict())

# %%
invalid_amounts = claims[claims['ApprovedAmount'] > claims['ClaimedAmount']]
log_issue("Claims_Fact", "ApprovedAmount", "Invalid Amount",
          "ApprovedAmount > ClaimedAmount", len(invalid_amounts),invalid_amounts[['ClaimID','ApprovedAmount','ClaimedAmount']].head().to_dict())

# %%
neg_amount = claims[claims['ClaimedAmount'] < 0]
log_issue("Claims_Fact", "ClaimedAmount", "Negative Amount",
          "ClaimedAmount < 0", len(neg_amount),neg_amount['ClaimedAmount'].head().to_dict())

# %% [markdown]
# # Outlier Detection (Z-Score)

# %%
claims.columns
# Out:
# Index(['ClaimID', 'MemberID', 'PolicyID', 'ProviderID', 'ClaimType',
#        'ClaimSubmissionDate', 'AdmissionDate', 'DischargeDate',
#        'ClaimedAmount', 'ApprovedAmount', 'ICDCode(s)', 'ProcedureCode(s)',
#        'PreAuthNumber', 'PreAuthStatus', 'QueryRaiseDate', 'SettlementDate',
#        'TPANotes', 'Currency', 'NetworkStatus'],
#       dtype='object')

# %%
claims['Procedure_list'] = claims['ProcedureCode(s)'].astype(str).str.split('|')
claims_proc_exploded = claims.explode('Procedure_list')

# %%
claims_proc_exploded
# Out:
#          ClaimID   MemberID   PolicyID ProviderID        ClaimType  \
# 0      CLM000001  MBR000418  POL001439  PRV000064              OPD
# 1      CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 1      CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 2      CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# 2      CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# ...          ...        ...        ...        ...              ...
# 11998  CLM011999  MBR008814  POL001365  PRV000048  Hospitalization
# 11999  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 11999  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 11999  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 11999  CLM012000  MBR005075  POL000130  PRV000247        Maternity
#
#       ClaimSubmissionDate AdmissionDate DischargeDate  ClaimedAmount  \
# 0              2023-08-07    2023-08-02    2023-08-02       11032.91
# 1              2024-12-12    2024-12-02    2024-12-02        3585.74
# 1              2024-12-12    2024-12-02    2024-12-02        3585.74
# 2              2025-06-21    2025-06-20    2025-06-23       35010.21
# 2              2025-06-21    2025-06-20    2025-06-23       35010.21
# ...                   ...           ...           ...            ...
# 11998          2025-09-27    2025-09-26    2025-09-26        5021.27
# 11999          2023-10-11    2023-10-11    2023-10-14       34593.01
# 11999          2023-10-11    2023-10-11    2023-10-14       34593.01
# 11999          2023-10-11    2023-10-11    2023-10-14       34593.01
# 11999          2023-10-11    2023-10-11    2023-10-14       34593.01
#
#        ApprovedAmount ICDCode(s)                 ProcedureCode(s)  \
# 0             9379.54  B20B|J18V                          PRC0014
# 1             2825.01       A09T                  PRC0090|PRC0025
# 1             2825.01       A09T                  PRC0090|PRC0025
# 2            29763.68        C50          PRC0102|PRC0017|PRC0074
# 2            29763.68        C50          PRC0102|PRC0017|PRC0074
# ...               ...        ...                              ...
# 11998         4222.51       M17K                          PRC0061
# 11999        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 11999        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 11999        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 11999        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
#
#       PreAuthNumber PreAuthStatus QueryRaiseDate SettlementDate  \
# 0               NaN  Not Required            NaT            NaT
# 1               NaN  Not Required            NaT     2024-12-26
# 1               NaN  Not Required            NaT     2024-12-26
# 2         PA-654823      Approved            NaT            NaT
# 2         PA-654823      Approved            NaT            NaT
# ...             ...           ...            ...            ...
# 11998     PA-148798      Approved            NaT     2025-10-27
# 11999     PA-337705      Approved            NaT     2023-11-10
# 11999     PA-337705      Approved            NaT     2023-11-10
# 11999     PA-337705      Approved            NaT     2023-11-10
# 11999     PA-337705      Approved            NaT     2023-11-10
#
#                                            TPANotes Currency   NetworkStatus  \
# 0                              Deductibles applied.      INR      In-Network
# 1                   Room rent exceeded eligibility.      INR  Out-of-Network
# 1                   Room rent exceeded eligibility.      INR  Out-of-Network
# 2                       Claim under medical review.      INR      In-Network
# 2                       Claim under medical review.      INR      In-Network
# ...                                             ...      ...             ...
# 11998  Investigation initiated for high-cost claim.      USD      In-Network
# 11999              Pre-auth approved as per policy.      INR      In-Network
# 11999              Pre-auth approved as per policy.      INR      In-Network
# 11999              Pre-auth approved as per policy.      INR      In-Network
# 11999              Pre-auth approved as per policy.      INR      In-Network
#
#       Procedure_list
# 0            PRC0014
# 1            PRC0090
# 1            PRC0025
# 2            PRC0102
# 2            PRC0017
# ...              ...
# 11998        PRC0061
# 11999        PRC0038
# 11999        PRC0097
# 11999        PRC0022
# 11999        PRC0036
#
# [23974 rows x 20 columns]

# %%
#Merge procedure categories first
claims_proc_exploded = claims_proc_exploded.merge(
    procedures[['ProcedureCode','ProcedureCategory','StandardRate']],
    left_on='Procedure_list', right_on='ProcedureCode',
    how='left'
)

# %%
claims_proc_exploded
# Out:
#          ClaimID   MemberID   PolicyID ProviderID        ClaimType  \
# 0      CLM000001  MBR000418  POL001439  PRV000064              OPD
# 1      CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 2      CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 3      CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# 4      CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# ...          ...        ...        ...        ...              ...
# 23969  CLM011999  MBR008814  POL001365  PRV000048  Hospitalization
# 23970  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 23971  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 23972  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 23973  CLM012000  MBR005075  POL000130  PRV000247        Maternity
#
#       ClaimSubmissionDate AdmissionDate DischargeDate  ClaimedAmount  \
# 0              2023-08-07    2023-08-02    2023-08-02       11032.91
# 1              2024-12-12    2024-12-02    2024-12-02        3585.74
# 2              2024-12-12    2024-12-02    2024-12-02        3585.74
# 3              2025-06-21    2025-06-20    2025-06-23       35010.21
# 4              2025-06-21    2025-06-20    2025-06-23       35010.21
# ...                   ...           ...           ...            ...
# 23969          2025-09-27    2025-09-26    2025-09-26        5021.27
# 23970          2023-10-11    2023-10-11    2023-10-14       34593.01
# 23971          2023-10-11    2023-10-11    2023-10-14       34593.01
# 23972          2023-10-11    2023-10-11    2023-10-14       34593.01
# 23973          2023-10-11    2023-10-11    2023-10-14       34593.01
#
#        ApprovedAmount ICDCode(s)                 ProcedureCode(s)  \
# 0             9379.54  B20B|J18V                          PRC0014
# 1             2825.01       A09T                  PRC0090|PRC0025
# 2             2825.01       A09T                  PRC0090|PRC0025
# 3            29763.68        C50          PRC0102|PRC0017|PRC0074
# 4            29763.68        C50          PRC0102|PRC0017|PRC0074
# ...               ...        ...                              ...
# 23969         4222.51       M17K                          PRC0061
# 23970        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 23971        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 23972        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 23973        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
#
#       PreAuthNumber PreAuthStatus QueryRaiseDate SettlementDate  \
# 0               NaN  Not Required            NaT            NaT
# 1               NaN  Not Required            NaT     2024-12-26
# 2               NaN  Not Required            NaT     2024-12-26
# 3         PA-654823      Approved            NaT            NaT
# 4         PA-654823      Approved            NaT            NaT
# ...             ...           ...            ...            ...
# 23969     PA-148798      Approved            NaT     2025-10-27
# 23970     PA-337705      Approved            NaT     2023-11-10
# 23971     PA-337705      Approved            NaT     2023-11-10
# 23972     PA-337705      Approved            NaT     2023-11-10
# 23973     PA-337705      Approved            NaT     2023-11-10
#
#                                            TPANotes Currency   NetworkStatus  \
# 0                              Deductibles applied.      INR      In-Network
# 1                   Room rent exceeded eligibility.      INR  Out-of-Network
# 2                   Room rent exceeded eligibility.      INR  Out-of-Network
# 3                       Claim under medical review.      INR      In-Network
# 4                       Claim under medical review.      INR      In-Network
# ...                                             ...      ...             ...
# 23969  Investigation initiated for high-cost claim.      USD      In-Network
# 23970              Pre-auth approved as per policy.      INR      In-Network
# 23971              Pre-auth approved as per policy.      INR      In-Network
# 23972              Pre-auth approved as per policy.      INR      In-Network
# 23973              Pre-auth approved as per policy.      INR      In-Network
#
#       Procedure_list ProcedureCode ProcedureCategory  StandardRate
# 0            PRC0014       PRC0014          Pharmacy       9580.69
# 1            PRC0090       PRC0090       Diagnostics       1530.24
# 2            PRC0025       PRC0025      Consultation       1754.04
# 3            PRC0102       PRC0102       RoomCharges      16410.67
# 4            PRC0017       PRC0017       RoomCharges      12867.07
# ...              ...           ...               ...           ...
# 23969        PRC0061       PRC0061       Diagnostics       4792.17
# 23970        PRC0038       PRC0038       Diagnostics       4122.71
# 23971        PRC0097       PRC0097          Pharmacy       1124.39
# 23972        PRC0022       PRC0022       RoomCharges      12392.34
# 23973        PRC0036       PRC0036       RoomCharges      17171.33
#
# [23974 rows x 23 columns]

# %%
claims['z_score_claim'] = claims_proc_exploded.groupby('ProcedureCategory')['ClaimedAmount']\
                                .transform(lambda x: (x - x.mean())/x.std(ddof=0))

outliers = claims[claims['z_score_claim'].abs() >= 3]

log_issue("Claims_Fact", "ClaimedAmount", "Outlier",
          "Z-score >= 3", len(outliers))

# %%
claims
# Out:
#          ClaimID   MemberID   PolicyID ProviderID        ClaimType  \
# 0      CLM000001  MBR000418  POL001439  PRV000064              OPD
# 1      CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 2      CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# 3      CLM000004  MBR002753  POL002521  PRV000004        Emergency
# 4      CLM000005  MBR008783  POL002459  PRV000261          DayCare
# ...          ...        ...        ...        ...              ...
# 11995  CLM011996  MBR000235  POL000815  PRV000182  Hospitalization
# 11996  CLM011997  MBR006547  POL001856  PRV000256          DayCare
# 11997  CLM011998  MBR002947  POL000356  PRV000288  Hospitalization
# 11998  CLM011999  MBR008814  POL001365  PRV000048  Hospitalization
# 11999  CLM012000  MBR005075  POL000130  PRV000247        Maternity
#
#       ClaimSubmissionDate AdmissionDate DischargeDate  ClaimedAmount  \
# 0              2023-08-07    2023-08-02    2023-08-02       11032.91
# 1              2024-12-12    2024-12-02    2024-12-02        3585.74
# 2              2025-06-21    2025-06-20    2025-06-23       35010.21
# 3              2023-06-05    2023-06-03    2023-06-06       65845.72
# 4              2023-09-06    2023-09-06    2023-09-09       15926.97
# ...                   ...           ...           ...            ...
# 11995          2023-07-30    2023-07-30    2023-08-02       28330.43
# 11996          2025-10-05    2025-10-05    2025-10-08      145781.14
# 11997          2023-08-10    2023-08-10    2023-08-10        1559.05
# 11998          2025-09-27    2025-09-26    2025-09-26        5021.27
# 11999          2023-10-11    2023-10-11    2023-10-14       34593.01
#
#        ApprovedAmount      ICDCode(s)                 ProcedureCode(s)  \
# 0             9379.54       B20B|J18V                          PRC0014
# 1             2825.01            A09T                  PRC0090|PRC0025
# 2            29763.68             C50          PRC0102|PRC0017|PRC0074
# 3            55665.14        K35V|I21          PRC0087|PRC0096|PRC0038
# 4            15119.08       G43E|C50G                  PRC0120|PRC0022
# ...               ...             ...                              ...
# 11995        23121.90  B20B|J18V|G43J          PRC0036|PRC0091|PRC0120
# 11996       123431.88            J18V  PRC0030|PRC0106|PRC0029|PRC0061
# 11997         1346.83       G43E|A09F                          PRC0090
# 11998         4222.51            M17K                          PRC0061
# 11999        29326.80             C50  PRC0038|PRC0097|PRC0022|PRC0036
#
#       PreAuthNumber PreAuthStatus QueryRaiseDate SettlementDate  \
# 0               NaN  Not Required            NaT            NaT
# 1               NaN  Not Required            NaT     2024-12-26
# 2         PA-654823      Approved            NaT            NaT
# 3         PA-928278      Approved            NaT     2023-07-05
# 4         PA-648481      Approved            NaT     2023-09-20
# ...             ...           ...            ...            ...
# 11995     PA-564018      Approved     2023-08-01     2023-08-13
# 11996     PA-177925      Approved            NaT     2025-10-19
# 11997     PA-342928      Approved     2023-08-15     2023-08-17
# 11998     PA-148798      Approved            NaT     2025-10-27
# 11999     PA-337705      Approved            NaT     2023-11-10
#
#                                            TPANotes Currency   NetworkStatus  \
# 0                              Deductibles applied.      INR      In-Network
# 1                   Room rent exceeded eligibility.      INR  Out-of-Network
# 2                       Claim under medical review.      INR      In-Network
# 3                              Deductibles applied.      INR      In-Network
# 4                       Further documents required.      INR      In-Network
# ...                                             ...      ...             ...
# 11995                       Awaiting itemized bill.      INR      In-Network
# 11996                   Non-payable items excluded.      EUR      In-Network
# 11997               Room rent exceeded eligibility.      INR      In-Network
# 11998  Investigation initiated for high-cost claim.      USD      In-Network
# 11999              Pre-auth approved as per policy.      INR      In-Network
#
#                              Procedure_list  z_score_claim
# 0                                 [PRC0014]      -0.375332
# 1                        [PRC0090, PRC0025]      -0.561791
# 2               [PRC0102, PRC0017, PRC0074]      -0.523397
# 3               [PRC0087, PRC0096, PRC0038]      -0.227467
# 4                        [PRC0120, PRC0022]      -0.227467
# ...                                     ...            ...
# 11995           [PRC0036, PRC0091, PRC0120]       0.307537
# 11996  [PRC0030, PRC0106, PRC0029, PRC0061]       1.143214
# 11997                             [PRC0090]       0.883388
# 11998                             [PRC0061]       0.742444
# 11999  [PRC0038, PRC0097, PRC0022, PRC0036]      -0.143071
#
# [12000 rows x 21 columns]

# %% [markdown]
# # validate ICD Codes

# %%
claims_proc_exploded
# Out:
#          ClaimID   MemberID   PolicyID ProviderID        ClaimType  \
# 0      CLM000001  MBR000418  POL001439  PRV000064              OPD
# 1      CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 2      CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 3      CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# 4      CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# ...          ...        ...        ...        ...              ...
# 23969  CLM011999  MBR008814  POL001365  PRV000048  Hospitalization
# 23970  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 23971  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 23972  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 23973  CLM012000  MBR005075  POL000130  PRV000247        Maternity
#
#       ClaimSubmissionDate AdmissionDate DischargeDate  ClaimedAmount  \
# 0              2023-08-07    2023-08-02    2023-08-02       11032.91
# 1              2024-12-12    2024-12-02    2024-12-02        3585.74
# 2              2024-12-12    2024-12-02    2024-12-02        3585.74
# 3              2025-06-21    2025-06-20    2025-06-23       35010.21
# 4              2025-06-21    2025-06-20    2025-06-23       35010.21
# ...                   ...           ...           ...            ...
# 23969          2025-09-27    2025-09-26    2025-09-26        5021.27
# 23970          2023-10-11    2023-10-11    2023-10-14       34593.01
# 23971          2023-10-11    2023-10-11    2023-10-14       34593.01
# 23972          2023-10-11    2023-10-11    2023-10-14       34593.01
# 23973          2023-10-11    2023-10-11    2023-10-14       34593.01
#
#        ApprovedAmount ICDCode(s)                 ProcedureCode(s)  \
# 0             9379.54  B20B|J18V                          PRC0014
# 1             2825.01       A09T                  PRC0090|PRC0025
# 2             2825.01       A09T                  PRC0090|PRC0025
# 3            29763.68        C50          PRC0102|PRC0017|PRC0074
# 4            29763.68        C50          PRC0102|PRC0017|PRC0074
# ...               ...        ...                              ...
# 23969         4222.51       M17K                          PRC0061
# 23970        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 23971        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 23972        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 23973        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
#
#       PreAuthNumber PreAuthStatus QueryRaiseDate SettlementDate  \
# 0               NaN  Not Required            NaT            NaT
# 1               NaN  Not Required            NaT     2024-12-26
# 2               NaN  Not Required            NaT     2024-12-26
# 3         PA-654823      Approved            NaT            NaT
# 4         PA-654823      Approved            NaT            NaT
# ...             ...           ...            ...            ...
# 23969     PA-148798      Approved            NaT     2025-10-27
# 23970     PA-337705      Approved            NaT     2023-11-10
# 23971     PA-337705      Approved            NaT     2023-11-10
# 23972     PA-337705      Approved            NaT     2023-11-10
# 23973     PA-337705      Approved            NaT     2023-11-10
#
#                                            TPANotes Currency   NetworkStatus  \
# 0                              Deductibles applied.      INR      In-Network
# 1                   Room rent exceeded eligibility.      INR  Out-of-Network
# 2                   Room rent exceeded eligibility.      INR  Out-of-Network
# 3                       Claim under medical review.      INR      In-Network
# 4                       Claim under medical review.      INR      In-Network
# ...                                             ...      ...             ...
# 23969  Investigation initiated for high-cost claim.      USD      In-Network
# 23970              Pre-auth approved as per policy.      INR      In-Network
# 23971              Pre-auth approved as per policy.      INR      In-Network
# 23972              Pre-auth approved as per policy.      INR      In-Network
# 23973              Pre-auth approved as per policy.      INR      In-Network
#
#       Procedure_list ProcedureCode ProcedureCategory  StandardRate
# 0            PRC0014       PRC0014          Pharmacy       9580.69
# 1            PRC0090       PRC0090       Diagnostics       1530.24
# 2            PRC0025       PRC0025      Consultation       1754.04
# 3            PRC0102       PRC0102       RoomCharges      16410.67
# 4            PRC0017       PRC0017       RoomCharges      12867.07
# ...              ...           ...               ...           ...
# 23969        PRC0061       PRC0061       Diagnostics       4792.17
# 23970        PRC0038       PRC0038       Diagnostics       4122.71
# 23971        PRC0097       PRC0097          Pharmacy       1124.39
# 23972        PRC0022       PRC0022       RoomCharges      12392.34
# 23973        PRC0036       PRC0036       RoomCharges      17171.33
#
# [23974 rows x 23 columns]

# %%
# ----------------------------------------------
# Validate ICD Codes (multi-code fields)
# ----------------------------------------------

# Step 1: Split ICDCode(s) into list
claims['ICD_list'] = claims['ICDCode(s)'].astype(str).str.split('|')

# Step 2: Explode list into separate rows
claims_exploded = claims.explode('ICD_list')

# Step 3: Validate each ICD code
invalid_icd_rows = claims_exploded[
    ~claims_exploded['ICD_list'].isin(diagnosis['ICDCode'])
]

# Step 4: Group by ClaimID to list invalid codes
invalid_by_claim = invalid_icd_rows.groupby('ClaimID')['ICD_list'].apply(list)

# Step 5: Log issue
log_issue(
    "Claims_Fact",
    "ICDCode(s)",
    "Invalid ICD Code",
    "One or more ICDs do not exist in Diagnosis_Master",
    len(invalid_by_claim),
    invalid_by_claim.head().to_dict()
)

invalid_by_claim.head()
# Out:
# Series([], Name: ICD_list, dtype: object)

# %% [markdown]
# # validate Procedure Codes

# %%
# ----------------------------------------------------
# Validate Procedure Codes (supports multi-code fields)
# ----------------------------------------------------

# Step 1: Split ProcedureCode(s) into list
# claims['Procedure_list'] = claims['ProcedureCode(s)'].astype(str).str.split('|')

# # Step 2: Explode list into separate rows
# claims_proc_exploded = claims.explode('Procedure_list')

# Step 3: Validate each procedure code against master
invalid_proc_rows = claims_proc_exploded[
    ~claims_proc_exploded['Procedure_list'].isin(procedures['ProcedureCode'])
]

# Step 4: Combine invalid codes per ClaimID
invalid_proc_by_claim = invalid_proc_rows.groupby('ClaimID')['Procedure_list'].apply(list)

#Step 5: Log issue
log_issue(
    "Claims_Fact",
    "ProcedureCode(s)",
    "Invalid Procedure Code",
    "One or more Procedure Codes do not exist in Procedure_Master",
    len(invalid_proc_by_claim),
    invalid_proc_by_claim.head().to_dict()
)

invalid_proc_by_claim.head()
# Out:
# Series([], Name: Procedure_list, dtype: object)

# %%
policy_check = claims.merge(
    policies[['PolicyID','StartDate','EndDate']],
    on='PolicyID',
    how='left'
)

invalid_policy = policy_check[
    ((policy_check['ClaimSubmissionDate'] < policy_check['StartDate']) |
      (policy_check['ClaimSubmissionDate'] > policy_check['EndDate']))
]

log_issue("Claims_Fact", "PolicyID", "Invalid Coverage",
          "Admission date outside policy period", len(invalid_policy),invalid_policy[['ClaimSubmissionDate','StartDate','EndDate']].head().to_dict())

# %%
len(invalid_policy)
# Out:
# 9435

# %%
policy_check = claims.merge(
    policies[['PolicyID','StartDate','EndDate']],
    on='PolicyID',
    how='left'
)

valid_policy = policy_check[
    ((policy_check['ClaimSubmissionDate'] >= policy_check['StartDate']) &
      (policy_check['ClaimSubmissionDate'] <= policy_check['EndDate']))
]

log_issue("Claims_Fact", "PolicyID", "valid Coverage",
          "Admission date within policy period", len(valid_policy),valid_policy[['ClaimSubmissionDate','StartDate','EndDate']].head().to_dict())

# %%
len(valid_policy)
# Out:
# 2565

# %% [markdown]
# # Package Rate Cross-Checks

# %%
claims_pkg = claims.merge(
    providers[['ProviderID', 'NetworkType', 'PackageRates']],
    on='ProviderID',
    how='left'
)

# %%
#claims['Procedure_list'] = claims['ProcedureCode(s)'].astype(str).str.split('|')
#claims_proc_exploded = claims.explode('Procedure_list')
# claims_proc_exploded = claims_proc_exploded.merge(
#     procedures[['ProcedureCode', 'StandardRate']],
#     left_on='Procedure_list',
#     right_on='ProcedureCode',
#     how='left'
# )
claims_proc_exploded
# Out:
#          ClaimID   MemberID   PolicyID ProviderID        ClaimType  \
# 0      CLM000001  MBR000418  POL001439  PRV000064              OPD
# 1      CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 2      CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 3      CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# 4      CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# ...          ...        ...        ...        ...              ...
# 23969  CLM011999  MBR008814  POL001365  PRV000048  Hospitalization
# 23970  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 23971  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 23972  CLM012000  MBR005075  POL000130  PRV000247        Maternity
# 23973  CLM012000  MBR005075  POL000130  PRV000247        Maternity
#
#       ClaimSubmissionDate AdmissionDate DischargeDate  ClaimedAmount  \
# 0              2023-08-07    2023-08-02    2023-08-02       11032.91
# 1              2024-12-12    2024-12-02    2024-12-02        3585.74
# 2              2024-12-12    2024-12-02    2024-12-02        3585.74
# 3              2025-06-21    2025-06-20    2025-06-23       35010.21
# 4              2025-06-21    2025-06-20    2025-06-23       35010.21
# ...                   ...           ...           ...            ...
# 23969          2025-09-27    2025-09-26    2025-09-26        5021.27
# 23970          2023-10-11    2023-10-11    2023-10-14       34593.01
# 23971          2023-10-11    2023-10-11    2023-10-14       34593.01
# 23972          2023-10-11    2023-10-11    2023-10-14       34593.01
# 23973          2023-10-11    2023-10-11    2023-10-14       34593.01
#
#        ApprovedAmount ICDCode(s)                 ProcedureCode(s)  \
# 0             9379.54  B20B|J18V                          PRC0014
# 1             2825.01       A09T                  PRC0090|PRC0025
# 2             2825.01       A09T                  PRC0090|PRC0025
# 3            29763.68        C50          PRC0102|PRC0017|PRC0074
# 4            29763.68        C50          PRC0102|PRC0017|PRC0074
# ...               ...        ...                              ...
# 23969         4222.51       M17K                          PRC0061
# 23970        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 23971        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 23972        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
# 23973        29326.80        C50  PRC0038|PRC0097|PRC0022|PRC0036
#
#       PreAuthNumber PreAuthStatus QueryRaiseDate SettlementDate  \
# 0               NaN  Not Required            NaT            NaT
# 1               NaN  Not Required            NaT     2024-12-26
# 2               NaN  Not Required            NaT     2024-12-26
# 3         PA-654823      Approved            NaT            NaT
# 4         PA-654823      Approved            NaT            NaT
# ...             ...           ...            ...            ...
# 23969     PA-148798      Approved            NaT     2025-10-27
# 23970     PA-337705      Approved            NaT     2023-11-10
# 23971     PA-337705      Approved            NaT     2023-11-10
# 23972     PA-337705      Approved            NaT     2023-11-10
# 23973     PA-337705      Approved            NaT     2023-11-10
#
#                                            TPANotes Currency   NetworkStatus  \
# 0                              Deductibles applied.      INR      In-Network
# 1                   Room rent exceeded eligibility.      INR  Out-of-Network
# 2                   Room rent exceeded eligibility.      INR  Out-of-Network
# 3                       Claim under medical review.      INR      In-Network
# 4                       Claim under medical review.      INR      In-Network
# ...                                             ...      ...             ...
# 23969  Investigation initiated for high-cost claim.      USD      In-Network
# 23970              Pre-auth approved as per policy.      INR      In-Network
# 23971              Pre-auth approved as per policy.      INR      In-Network
# 23972              Pre-auth approved as per policy.      INR      In-Network
# 23973              Pre-auth approved as per policy.      INR      In-Network
#
#       Procedure_list ProcedureCode ProcedureCategory  StandardRate
# 0            PRC0014       PRC0014          Pharmacy       9580.69
# 1            PRC0090       PRC0090       Diagnostics       1530.24
# 2            PRC0025       PRC0025      Consultation       1754.04
# 3            PRC0102       PRC0102       RoomCharges      16410.67
# 4            PRC0017       PRC0017       RoomCharges      12867.07
# ...              ...           ...               ...           ...
# 23969        PRC0061       PRC0061       Diagnostics       4792.17
# 23970        PRC0038       PRC0038       Diagnostics       4122.71
# 23971        PRC0097       PRC0097          Pharmacy       1124.39
# 23972        PRC0022       PRC0022       RoomCharges      12392.34
# 23973        PRC0036       PRC0036       RoomCharges      17171.33
#
# [23974 rows x 23 columns]

# %%
standard_sum = claims_proc_exploded.groupby('ClaimID')['StandardRate'].sum().reset_index()
standard_sum = standard_sum.rename(columns={"StandardRate": "TotalStandardRate"})

claims_std = claims.merge(standard_sum, on='ClaimID', how='left')

claims_std['min_allowed'] = claims_std['TotalStandardRate'] * 0.9
claims_std['max_allowed'] = claims_std['TotalStandardRate'] * 1.1


package_mismatch = claims_std[
    (claims_std['TotalStandardRate'].notna()) &
    (
        (claims_std['ClaimedAmount'] < claims_std['min_allowed']) |
        (claims_std['ClaimedAmount'] > claims_std['max_allowed'])
    )
]


log_issue(
    "Claims_Fact",
    "ClaimedAmount",
    "StandardRate Package Mismatch",
    "ClaimedAmount not within ±10% of total StandardRate for procedures",
    len(package_mismatch),
    package_mismatch[['ClaimID', 'ClaimedAmount', 'TotalStandardRate', 'min_allowed', 'max_allowed']].head().to_dict()
)

# %%
claims.columns
# Out:
# Index(['ClaimID', 'MemberID', 'PolicyID', 'ProviderID', 'ClaimType',
#        'ClaimSubmissionDate', 'AdmissionDate', 'DischargeDate',
#        'ClaimedAmount', 'ApprovedAmount', 'ICDCode(s)', 'ProcedureCode(s)',
#        'PreAuthNumber', 'PreAuthStatus', 'QueryRaiseDate', 'SettlementDate',
#        'TPANotes', 'Currency', 'NetworkStatus', 'Procedure_list',
#        'z_score_claim', 'ICD_list'],
#       dtype='object')

# %%
claims["SettlementDate"].isnull().sum()
# Out:
# np.int64(1234)

# %% [markdown]
# # Out of network variance vs in-network

# %%
claims_std
# Out:
#          ClaimID   MemberID   PolicyID ProviderID        ClaimType  \
# 0      CLM000001  MBR000418  POL001439  PRV000064              OPD
# 1      CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 2      CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# 3      CLM000004  MBR002753  POL002521  PRV000004        Emergency
# 4      CLM000005  MBR008783  POL002459  PRV000261          DayCare
# ...          ...        ...        ...        ...              ...
# 11995  CLM011996  MBR000235  POL000815  PRV000182  Hospitalization
# 11996  CLM011997  MBR006547  POL001856  PRV000256          DayCare
# 11997  CLM011998  MBR002947  POL000356  PRV000288  Hospitalization
# 11998  CLM011999  MBR008814  POL001365  PRV000048  Hospitalization
# 11999  CLM012000  MBR005075  POL000130  PRV000247        Maternity
#
#       ClaimSubmissionDate AdmissionDate DischargeDate  ClaimedAmount  \
# 0              2023-08-07    2023-08-02    2023-08-02       11032.91
# 1              2024-12-12    2024-12-02    2024-12-02        3585.74
# 2              2025-06-21    2025-06-20    2025-06-23       35010.21
# 3              2023-06-05    2023-06-03    2023-06-06       65845.72
# 4              2023-09-06    2023-09-06    2023-09-09       15926.97
# ...                   ...           ...           ...            ...
# 11995          2023-07-30    2023-07-30    2023-08-02       28330.43
# 11996          2025-10-05    2025-10-05    2025-10-08      145781.14
# 11997          2023-08-10    2023-08-10    2023-08-10        1559.05
# 11998          2025-09-27    2025-09-26    2025-09-26        5021.27
# 11999          2023-10-11    2023-10-11    2023-10-14       34593.01
#
#        ApprovedAmount      ICDCode(s)                 ProcedureCode(s)  \
# 0             9379.54       B20B|J18V                          PRC0014
# 1             2825.01            A09T                  PRC0090|PRC0025
# 2            29763.68             C50          PRC0102|PRC0017|PRC0074
# 3            55665.14        K35V|I21          PRC0087|PRC0096|PRC0038
# 4            15119.08       G43E|C50G                  PRC0120|PRC0022
# ...               ...             ...                              ...
# 11995        23121.90  B20B|J18V|G43J          PRC0036|PRC0091|PRC0120
# 11996       123431.88            J18V  PRC0030|PRC0106|PRC0029|PRC0061
# 11997         1346.83       G43E|A09F                          PRC0090
# 11998         4222.51            M17K                          PRC0061
# 11999        29326.80             C50  PRC0038|PRC0097|PRC0022|PRC0036
#
#       PreAuthNumber PreAuthStatus QueryRaiseDate SettlementDate  \
# 0               NaN  Not Required            NaT            NaT
# 1               NaN  Not Required            NaT     2024-12-26
# 2         PA-654823      Approved            NaT            NaT
# 3         PA-928278      Approved            NaT     2023-07-05
# 4         PA-648481      Approved            NaT     2023-09-20
# ...             ...           ...            ...            ...
# 11995     PA-564018      Approved     2023-08-01     2023-08-13
# 11996     PA-177925      Approved            NaT     2025-10-19
# 11997     PA-342928      Approved     2023-08-15     2023-08-17
# 11998     PA-148798      Approved            NaT     2025-10-27
# 11999     PA-337705      Approved            NaT     2023-11-10
#
#                                            TPANotes Currency   NetworkStatus  \
# 0                              Deductibles applied.      INR      In-Network
# 1                   Room rent exceeded eligibility.      INR  Out-of-Network
# 2                       Claim under medical review.      INR      In-Network
# 3                              Deductibles applied.      INR      In-Network
# 4                       Further documents required.      INR      In-Network
# ...                                             ...      ...             ...
# 11995                       Awaiting itemized bill.      INR      In-Network
# 11996                   Non-payable items excluded.      EUR      In-Network
# 11997               Room rent exceeded eligibility.      INR      In-Network
# 11998  Investigation initiated for high-cost claim.      USD      In-Network
# 11999              Pre-auth approved as per policy.      INR      In-Network
#
#                              Procedure_list  z_score_claim  \
# 0                                 [PRC0014]      -0.375332
# 1                        [PRC0090, PRC0025]      -0.561791
# 2               [PRC0102, PRC0017, PRC0074]      -0.523397
# 3               [PRC0087, PRC0096, PRC0038]      -0.227467
# 4                        [PRC0120, PRC0022]      -0.227467
# ...                                     ...            ...
# 11995           [PRC0036, PRC0091, PRC0120]       0.307537
# 11996  [PRC0030, PRC0106, PRC0029, PRC0061]       1.143214
# 11997                             [PRC0090]       0.883388
# 11998                             [PRC0061]       0.742444
# 11999  [PRC0038, PRC0097, PRC0022, PRC0036]      -0.143071
#
#                  ICD_list  TotalStandardRate  min_allowed  max_allowed
# 0            [B20B, J18V]            9580.69     8622.621    10538.759
# 1                  [A09T]            3284.28     2955.852     3612.708
# 2                   [C50]           29723.35    26751.015    32695.685
# 3             [K35V, I21]           55913.66    50322.294    61505.026
# 4            [G43E, C50G]           15498.65    13948.785    17048.515
# ...                   ...                ...          ...          ...
# 11995  [B20B, J18V, G43J]           24646.00    22181.400    27110.600
# 11996              [J18V]          139541.42   125587.278   153495.562
# 11997        [G43E, A09F]            1530.24     1377.216     1683.264
# 11998              [M17K]            4792.17     4312.953     5271.387
# 11999               [C50]           34810.77    31329.693    38291.847
#
# [12000 rows x 25 columns]

# %%
network_summary = claims_std.groupby('NetworkStatus')['ClaimedAmount'].mean()
in_net_avg = network_summary.get('In-Network', None)

# %%
network_summary
# Out:
# NetworkStatus
# In-Network        54089.031499
# Out-of-Network    54756.415731
# Name: ClaimedAmount, dtype: float64

# %%
in_net_avg
# Out:
# np.float64(54089.03149895982)

# %%
if in_net_avg is not None:
    claims_std['out_net_variance_flag'] = (
        (claims_std['NetworkStatus'] == 'Out-of-Network') &
        (claims_std['ClaimedAmount'] > in_net_avg * 1.20) # 54089.031 * 1.20 = 64906.8372
    )
else:
    claims_std['out_net_variance_flag'] = False

# %%
# Boolean Filtering df[condition]
out_net_variance_claims = claims_std[claims_std['out_net_variance_flag']]

# %%
log_issue(
    "Claims_Fact",
    "ClaimedAmount",
    "Out-of-Network Variance",
    "Out-of-Network ClaimedAmount > 120% of In-Network average",
    len(out_net_variance_claims),
    out_net_variance_claims[['ClaimID','ClaimedAmount','NetworkStatus']].head().to_dict()
)

# %%
claims_std.head(23)
# Out:
#       ClaimID   MemberID   PolicyID ProviderID        ClaimType  \
# 0   CLM000001  MBR000418  POL001439  PRV000064              OPD
# 1   CLM000002  MBR001547  POL000009  PRV000281  Hospitalization
# 2   CLM000003  MBR002778  POL002455  PRV000083  Hospitalization
# 3   CLM000004  MBR002753  POL002521  PRV000004        Emergency
# 4   CLM000005  MBR008783  POL002459  PRV000261          DayCare
# 5   CLM000006  MBR007793  POL000644  PRV000070  Hospitalization
# 6   CLM000007  MBR006831  POL000979  PRV000164  Hospitalization
# 7   CLM000008  MBR004416  POL001707  PRV000003        Emergency
# 8   CLM000009  MBR006056  POL001388  PRV000170  Hospitalization
# 9   CLM000010  MBR005463  POL002410  PRV000114  Hospitalization
# 10  CLM000011  MBR006283  POL002223  PRV000316              OPD
# 11  CLM000012  MBR005119  POL000094  PRV000123  Hospitalization
# 12  CLM000013  MBR001590  POL001244  PRV000349  Hospitalization
# 13  CLM000014  MBR006952  POL001883  PRV000031        Maternity
# 14  CLM000015  MBR001075  POL000537  PRV000292              OPD
# 15  CLM000016  MBR005687  POL001489  PRV000147              OPD
# 16  CLM000017  MBR007802  POL000637  PRV000224  Hospitalization
# 17  CLM000018  MBR007653  POL002802  PRV000285              OPD
# 18  CLM000019  MBR004683  POL001469  PRV000154  Hospitalization
# 19  CLM000020  MBR000390  POL001263  PRV000300        Emergency
# 20  CLM000021  MBR003139  POL000441  PRV000103  Hospitalization
# 21  CLM000022  MBR005921  POL000059  PRV000147          DayCare
# 22  CLM000023  MBR003460  POL001707  PRV000262        Maternity
#
#    ClaimSubmissionDate AdmissionDate DischargeDate  ClaimedAmount  \
# 0           2023-08-07    2023-08-02    2023-08-02       11032.91
# 1           2024-12-12    2024-12-02    2024-12-02        3585.74
# 2           2025-06-21    2025-06-20    2025-06-23       35010.21
# 3           2023-06-05    2023-06-03    2023-06-06       65845.72
# 4           2023-09-06    2023-09-06    2023-09-09       15926.97
# 5           2023-10-13    2023-10-11    2023-10-11        1093.58
# 6           2025-02-21    2025-02-20    2025-02-23       13163.49
# 7           2023-05-09    2023-05-08    2023-05-15      196014.60
# 8           2025-04-16    2025-04-16    2025-04-23      270121.44
# 9           2023-02-17    2023-02-05    2023-02-12       43846.84
# 10          2025-06-21    2025-06-08    2025-06-11      181538.55
# 11          2024-12-28    2024-12-28    2025-01-02      151542.51
# 12          2024-10-22    2024-10-22    2024-10-25        6224.01
# 13          2023-05-20    2023-05-19    2023-05-19        1075.65
# 14          2023-02-04    2023-02-02    2023-02-02        1533.87
# 15          2025-11-07    2025-11-05    2025-11-05        4913.10
# 16          2023-07-08    2023-07-08    2023-07-08        3721.83
# 17          2024-02-06    2024-01-22    2024-01-22        5417.05
# 18          2025-01-06    2025-01-06    2025-01-06        2776.38
# 19          2024-01-16    2024-01-14    2024-01-17       87453.83
# 20          2024-05-24    2024-05-24    2024-05-24        3942.43
# 21          2023-07-12    2023-07-11    2023-07-18      211506.82
# 22          2023-12-06    2023-11-26    2023-12-01      326133.83
#
#     ApprovedAmount      ICDCode(s)                 ProcedureCode(s)  \
# 0          9379.54       B20B|J18V                          PRC0014
# 1          2825.01            A09T                  PRC0090|PRC0025
# 2         29763.68             C50          PRC0102|PRC0017|PRC0074
# 3         55665.14        K35V|I21          PRC0087|PRC0096|PRC0038
# 4         15119.08       G43E|C50G                  PRC0120|PRC0022
# 5           838.92            G40L                          PRC0092
# 6         12040.09            C50G                  PRC0018|PRC0084
# 7        165146.42            M17F                  PRC0058|PRC0068
# 8        228712.38        A09F|S83          PRC0077|PRC0108|PRC0055
# 9         33698.34         M17|G40                  PRC0081|PRC0071
# 10       162897.12  A09T|N20S|O14Q  PRC0120|PRC0080|PRC0001|PRC0046
# 11       123385.40            N20S                          PRC0048
# 12         5544.92            M17F                          PRC0041
# 13          995.67        K40|S83Q                          PRC0026
# 14         1403.53        J18|E11Q                          PRC0057
# 15         4190.26            G43J                          PRC0091
# 16         3310.69       G40S|C50D                  PRC0110|PRC0064
# 17         5114.18             E11  PRC0031|PRC0026|PRC0064|PRC0033
# 18         2295.10   A09|G43E|I21H                          PRC0086
# 19        75935.23       B20C|E11Q                  PRC0037|PRC0021
# 20         3484.08             K40                          PRC0056
# 21       179333.57       M17F|G43B          PRC0091|PRC0063|PRC0117
# 22       249738.95             I21          PRC0077|PRC0015|PRC0105
#
#    PreAuthNumber PreAuthStatus QueryRaiseDate SettlementDate  \
# 0            NaN  Not Required            NaT            NaT
# 1            NaN  Not Required            NaT     2024-12-26
# 2      PA-654823      Approved            NaT            NaT
# 3      PA-928278      Approved            NaT     2023-07-05
# 4      PA-648481      Approved            NaT     2023-09-20
# 5            NaN  Not Required            NaT     2023-10-20
# 6      PA-458318      Approved            NaT     2025-02-28
# 7      PA-706205      Approved     2023-05-16     2023-05-16
# 8      PA-183662       Pending            NaT     2025-04-23
# 9            NaN  Not Required     2023-02-22     2023-03-03
# 10           NaN  Not Required            NaT     2025-07-12
# 11     PA-705125      Approved            NaT     2025-01-18
# 12     PA-543504       Pending            NaT     2024-11-12
# 13     PA-758510      Approved            NaT     2023-06-10
# 14           NaN  Not Required            NaT     2023-02-18
# 15           NaN  Not Required            NaT     2025-11-14
# 16     PA-227780       Pending     2023-07-13     2023-07-22
# 17           NaN  Not Required     2024-02-08     2024-02-20
# 18     PA-422304       Pending            NaT     2025-02-05
# 19     PA-858652      Approved            NaT            NaT
# 20     PA-966492       Pending            NaT     2024-07-08
# 21     PA-144791      Approved     2023-07-17     2023-08-26
# 22           NaN  Not Required            NaT     2023-12-13
#
#                                         TPANotes Currency   NetworkStatus  \
# 0                           Deductibles applied.      INR      In-Network
# 1                Room rent exceeded eligibility.      INR  Out-of-Network
# 2                    Claim under medical review.      INR      In-Network
# 3                           Deductibles applied.      INR      In-Network
# 4                    Further documents required.      INR      In-Network
# 5   Investigation initiated for high-cost claim.      INR  Out-of-Network
# 6                           Deductibles applied.      INR      In-Network
# 7                    Non-payable items excluded.      INR      In-Network
# 8                        Awaiting itemized bill.      INR      In-Network
# 9                        Awaiting itemized bill.      INR  Out-of-Network
# 10                       Awaiting itemized bill.      EUR      In-Network
# 11                   Claim under medical review.      INR      In-Network
# 12              Pre-auth approved as per policy.      INR      In-Network
# 13                   Claim under medical review.      INR      In-Network
# 14         Policy waiting period clause applied.      INR      In-Network
# 15               Room rent exceeded eligibility.      INR      In-Network
# 16               Room rent exceeded eligibility.      INR      In-Network
# 17                  Requested discharge summary.      INR      In-Network
# 18                       Awaiting itemized bill.      INR      In-Network
# 19         Policy waiting period clause applied.      INR      In-Network
# 20                  Requested discharge summary.      INR      In-Network
# 21                          Deductibles applied.      INR      In-Network
# 22               Room rent exceeded eligibility.      INR  Out-of-Network
#
#                           Procedure_list  z_score_claim            ICD_list  \
# 0                              [PRC0014]      -0.375332        [B20B, J18V]
# 1                     [PRC0090, PRC0025]      -0.561791              [A09T]
# 2            [PRC0102, PRC0017, PRC0074]      -0.523397               [C50]
# 3            [PRC0087, PRC0096, PRC0038]      -0.227467         [K35V, I21]
# 4                     [PRC0120, PRC0022]      -0.227467        [G43E, C50G]
# 5                              [PRC0092]      -0.056357              [G40L]
# 6                     [PRC0018, PRC0084]       0.213080              [C50G]
# 7                     [PRC0058, PRC0068]      -0.094273              [M17F]
# 8            [PRC0077, PRC0108, PRC0055]       0.296084         [A09F, S83]
# 9                     [PRC0081, PRC0071]      -0.391742          [M17, G40]
# 10  [PRC0120, PRC0080, PRC0001, PRC0046]      -0.500108  [A09T, N20S, O14Q]
# 11                             [PRC0048]      -0.560437              [N20S]
# 12                             [PRC0041]      -0.429820              [M17F]
# 13                             [PRC0026]      -0.539590         [K40, S83Q]
# 14                             [PRC0057]       1.203671         [J18, E11Q]
# 15                             [PRC0091]      -0.382814              [G43J]
# 16                    [PRC0110, PRC0064]       0.394575        [G40S, C50D]
# 17  [PRC0031, PRC0026, PRC0064, PRC0033]       2.024104               [E11]
# 18                             [PRC0086]       2.024104   [A09, G43E, I21H]
# 19                    [PRC0037, PRC0021]      -0.480969        [B20C, E11Q]
# 20                             [PRC0056]       0.074976               [K40]
# 21           [PRC0091, PRC0063, PRC0117]       1.890205        [M17F, G43B]
# 22           [PRC0077, PRC0015, PRC0105]       1.812018               [I21]
#
#     TotalStandardRate  min_allowed  max_allowed  out_net_variance_flag
# 0             9580.69     8622.621    10538.759                  False
# 1             3284.28     2955.852     3612.708                  False
# 2            29723.35    26751.015    32695.685                  False
# 3            55913.66    50322.294    61505.026                  False
# 4            15498.65    13948.785    17048.515                  False
# 5             1174.07     1056.663     1291.477                  False
# 6            13669.59    12302.631    15036.549                  False
# 7           209815.63   188834.067   230797.193                  False
# 8           257871.21   232084.089   283658.331                  False
# 9            40866.40    36779.760    44953.040                  False
# 10          154490.91   139041.819   169940.001                  False
# 11          162667.36   146400.624   178934.096                  False
# 12            5827.28     5244.552     6410.008                  False
# 13             946.21      851.589     1040.831                  False
# 14            1458.91     1313.019     1604.801                  False
# 15            4368.36     3931.524     4805.196                  False
# 16            3654.70     3289.230     4020.170                  False
# 17            5862.95     5276.655     6449.245                  False
# 18            2402.03     2161.827     2642.233                  False
# 19           87030.12    78327.108    95733.132                  False
# 20            3561.28     3205.152     3917.408                  False
# 21          201303.44   181173.096   221433.784                  False
# 22          346696.87   312027.183   381366.557                   True

# %%
out_net_variance_claims
# Out:
#          ClaimID   MemberID   PolicyID ProviderID        ClaimType  \
# 22     CLM000023  MBR003460  POL001707  PRV000262        Maternity
# 30     CLM000031  MBR002158  POL000092  PRV000199  Hospitalization
# 51     CLM000052  MBR002262  POL000957  PRV000231  Hospitalization
# 70     CLM000071  MBR004619  POL001003  PRV000128  Hospitalization
# 77     CLM000078  MBR007645  POL000742  PRV000140          DayCare
# ...          ...        ...        ...        ...              ...
# 11824  CLM011825  MBR004051  POL000811  PRV000241          DayCare
# 11956  CLM011957  MBR002362  POL002127  PRV000198  Hospitalization
# 11972  CLM011973  MBR004767  POL000277  PRV000183          DayCare
# 11973  CLM011974  MBR007924  POL000782  PRV000036  Hospitalization
# 11980  CLM011981  MBR003588  POL001800  PRV000246          DayCare
#
#       ClaimSubmissionDate AdmissionDate DischargeDate  ClaimedAmount  \
# 22             2023-12-06    2023-11-26    2023-12-01      326133.83
# 30             2024-08-15    2024-08-06    2024-08-13       93574.65
# 51             2024-05-30    2024-05-25    2024-05-28       94358.34
# 70             2024-03-18    2024-03-06    2024-03-13      190028.60
# 77             2024-08-22    2024-08-15    2024-08-20      232882.10
# ...                   ...           ...           ...            ...
# 11824          2024-04-27    2024-04-19    2024-04-22       90821.71
# 11956          2023-06-22    2023-06-17    2023-06-20      114915.66
# 11972          2023-05-15    2023-05-06    2023-05-13      294731.11
# 11973          2023-07-31    2023-07-23    2023-07-26       90387.11
# 11980          2023-10-11    2023-10-01    2023-10-06      189136.72
#
#        ApprovedAmount     ICDCode(s)                 ProcedureCode(s)  \
# 22          249738.95            I21          PRC0077|PRC0015|PRC0105
# 30           66319.07        G40|M17          PRC0035|PRC0066|PRC0119
# 51           70251.34           N20S          PRC0093|PRC0084|PRC0001
# 70          141624.20           M17F          PRC0048|PRC0117|PRC0059
# 77          164371.32      M17K|G43J                          PRC0003
# ...               ...            ...                              ...
# 11824        71432.93       J18T|N39          PRC0064|PRC0021|PRC0087
# 11956        78499.35           A09T  PRC0026|PRC0110|PRC0062|PRC0090
# 11972       227651.65           M17F                  PRC0051|PRC0019
# 11973        64524.53  I21Y|G43|G40M                          PRC0065
# 11980       150117.44       J18|N39V                  PRC0032|PRC0038
#
#       PreAuthNumber PreAuthStatus QueryRaiseDate SettlementDate  \
# 22              NaN  Not Required            NaT     2023-12-13
# 30              NaN  Not Required     2024-08-25     2024-08-22
# 51              NaN  Not Required     2024-06-04     2024-06-29
# 70              NaN  Not Required            NaT     2024-05-02
# 77              NaN  Not Required            NaT     2024-08-29
# ...             ...           ...            ...            ...
# 11824           NaN  Not Required     2024-05-04     2024-05-04
# 11956           NaN  Not Required            NaT     2023-06-29
# 11972           NaN  Not Required            NaT     2023-06-05
# 11973           NaN  Not Required            NaT     2023-08-30
# 11980           NaN  Not Required     2023-10-13     2023-10-25
#
#                                            TPANotes Currency   NetworkStatus  \
# 22                  Room rent exceeded eligibility.      INR  Out-of-Network
# 30                      Claim under medical review.      INR  Out-of-Network
# 51                      Non-payable items excluded.      INR  Out-of-Network
# 70                     Requested discharge summary.      INR  Out-of-Network
# 77                     Requested discharge summary.      EUR  Out-of-Network
# ...                                             ...      ...             ...
# 11824  Investigation initiated for high-cost claim.      INR  Out-of-Network
# 11956                   Claim under medical review.      EUR  Out-of-Network
# 11972               Room rent exceeded eligibility.      INR  Out-of-Network
# 11973                   Non-payable items excluded.      INR  Out-of-Network
# 11980               Room rent exceeded eligibility.      INR  Out-of-Network
#
#                              Procedure_list  z_score_claim           ICD_list  \
# 22              [PRC0077, PRC0015, PRC0105]       1.812018              [I21]
# 30              [PRC0035, PRC0066, PRC0119]      -0.521375         [G40, M17]
# 51              [PRC0093, PRC0084, PRC0001]      -1.034079             [N20S]
# 70              [PRC0048, PRC0117, PRC0059]      -0.534319             [M17F]
# 77                                [PRC0003]       2.276689       [M17K, G43J]
# ...                                     ...            ...                ...
# 11824           [PRC0064, PRC0021, PRC0087]      -0.652065        [J18T, N39]
# 11956  [PRC0026, PRC0110, PRC0062, PRC0090]       3.349622             [A09T]
# 11972                    [PRC0051, PRC0019]      -0.628555             [M17F]
# 11973                             [PRC0065]       0.008421  [I21Y, G43, G40M]
# 11980                    [PRC0032, PRC0038]      -0.553741        [J18, N39V]
#
#        TotalStandardRate  min_allowed  max_allowed  out_net_variance_flag
# 22             346696.87   312027.183   381366.557                   True
# 30              80790.92    72711.828    88870.012                   True
# 51              82091.43    73882.287    90300.573                   True
# 70             201459.51   181313.559   221605.461                   True
# 77             226211.94   203590.746   248833.134                   True
# ...                  ...          ...          ...                    ...
# 11824           89657.90    80692.110    98623.690                   True
# 11956          101961.76    91765.584   112157.936                   True
# 11972          252399.40   227159.460   277639.340                   True
# 11973           86541.89    77887.701    95196.079                   True
# 11980          173681.88   156313.692   191050.068                   True
#
# [786 rows x 26 columns]

# %%
# Normalize PreAuthStatus to avoid case mismatches
claims['PreAuthStatus'] = claims['PreAuthStatus'].astype(str).str.upper().str.strip()

# Define rejection keywords
rejection_keywords = ["REJECT", "DENY", "NOT APPROVED", "DECLINED"]

# Flag based on ApprovedAmount
flag_amt = (claims['ApprovedAmount'].fillna(0) == 0).astype(int)

# Flag based on PreAuthStatus text
flag_pre_auth = claims['PreAuthStatus'].apply(
    lambda x: 1 if any(keyword in x for keyword in rejection_keywords) else 0
)

# (Optional) TPANotes rejection check
claims['TPANotes'] = claims['TPANotes'].astype(str).str.upper().str.strip()
flag_notes = claims['TPANotes'].apply(
    lambda x: 1 if any(keyword in x for keyword in rejection_keywords) else 0
)

# Final Rejected Flag
claims['Rejected_flag'] = (
    flag_amt | flag_pre_auth | flag_notes
).astype(int)

sample_vals = claims.loc[claims['Rejected_flag'] == 1, 'ClaimID'].head(5).tolist()

# Log issue count for audit
log_issue("Claims_Fact", "Rejected_flag", "Rejection Flag",
          "ApprovedAmount=0 or PreAuthStatus/TPANotes indicates rejection",
          claims['Rejected_flag'].sum(),sample_vals)

# %%
audit_df = pd.DataFrame(audit_log)
audit_df.to_csv("audit_log.csv", index=False)
audit_df.head(20)
# Out:
#               table            column                     issue_type  \
# 0       Claims_Fact           ClaimID                  Duplicate Key
# 1   Provider_Master        ProviderID                  Duplicate Key
# 2     Member_Master          MemberID                  Duplicate Key
# 3     Policy_Master          PolicyID                  Duplicate Key
# 4       Claims_Fact     DischargeDate             Invalid Date Order
# 5       Claims_Fact    SettlementDate             Invalid Date Order
# 6       Claims_Fact     DischargeDate                        Missing
# 7       Claims_Fact    SettlementDate                        Missing
# 8       Claims_Fact    ApprovedAmount                 Invalid Amount
# 9       Claims_Fact     ClaimedAmount                Negative Amount
# 10      Claims_Fact     ClaimedAmount                        Outlier
# 11      Claims_Fact        ICDCode(s)               Invalid ICD Code
# 12      Claims_Fact  ProcedureCode(s)         Invalid Procedure Code
# 13      Claims_Fact          PolicyID               Invalid Coverage
# 14      Claims_Fact          PolicyID                 valid Coverage
# 15      Claims_Fact     ClaimedAmount  StandardRate Package Mismatch
# 16      Claims_Fact     ClaimedAmount        Out-of-Network Variance
# 17      Claims_Fact     Rejected_flag                 Rejection Flag
#
#                                                  rule  rows_affected  \
# 0                              ClaimID must be unique              0
# 1                           ProviderID must be unique              0
# 2                             MemberID must be unique              0
# 3                             PolicyID must be unique              0
# 4                       DischargeDate < AdmissionDate              0
# 5                SettlementDate < ClaimSubmissionDate              0
# 6                               DischargeDate is NULL              0
# 7                              SettlementDate is NULL           1234
# 8                      ApprovedAmount > ClaimedAmount              0
# 9                                   ClaimedAmount < 0              0
# 10                                       Z-score >= 3            286
# 11  One or more ICDs do not exist in Diagnosis_Master              0
# 12  One or more Procedure Codes do not exist in Pr...              0
# 13               Admission date outside policy period           9435
# 14                Admission date within policy period           2565
# 15  ClaimedAmount not within ±10% of total Standar...           4049
# 16  Out-of-Network ClaimedAmount > 120% of In-Netw...            786
# 17  ApprovedAmount=0 or PreAuthStatus/TPANotes ind...            359
#
#                                         sample_values
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   {'ClaimID': {}, 'AdmissionDate': {}, 'Discharg...
# 5   {'ClaimID': {}, 'SettlementDate': {}, 'ClaimSu...
# 6                                                  {}
# 7   {0: 'CLM000001', 2: 'CLM000003', 19: 'CLM00002...
# 8   {'ClaimID': {}, 'ApprovedAmount': {}, 'Claimed...
# 9                                                  {}
# 10                                               None
# 11                                                 {}
# 12                                                 {}
# 13  {'ClaimSubmissionDate': {0: 2023-08-07 00:00:0...
# 14  {'ClaimSubmissionDate': {6: 2025-02-21 00:00:0...
# 15  {'ClaimID': {0: 'CLM000001', 2: 'CLM000003', 3...
# 16  {'ClaimID': {22: 'CLM000023', 30: 'CLM000031',...
# 17  [CLM000026, CLM000112, CLM000134, CLM000158, C...

# %%
claims_std.to_csv("Claims_Fact_clean.csv", index=False)
# providers.to_csv("Provider_Master_clean.csv", index=False)
# members.to_csv("Member_Master_clean.csv", index=False)
# policies.to_csv("Policy_Master_clean.csv", index=False)
